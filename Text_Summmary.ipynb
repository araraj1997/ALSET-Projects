# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/araraj1997/Recommendation-Systems/blob/master/Text_Summmary.ipynb)

# %%
#@title
from apiclient.discovery import build
from apiclient.errors import HttpError
import nltk
DEVELOPER_KEY = "AIzaSyCnu-cNV86wvwepVA3IAm2KIPZCVV876Z4"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

def get_comment_threads(youtube, video_id):
  results = youtube.commentThreads().list(
    part="snippet",
    maxResults=100,
    videoId=video_id,
    textFormat="plainText"
  ).execute()
  all_text = []
  for item in results["items"]:
    comment = item["snippet"]["topLevelComment"]
    author = comment["snippet"]["authorDisplayName"]
    text = comment["snippet"]["textDisplay"]
    
    all_text.append(text)
    
  text_join = ' '.join(all_text)

  return text_join

def get_video_title(video_id):
  results = youtube.videos().list(
    part='snippet',
    id=video_id
  ).execute()
  print(results.keys())
  
  for item in results["items"]:
    title = item['snippet']['title']
  
  return title

# %%
# !pip install gensim

# %%
from gensim.summarization.summarizer import summarize
from gensim.summarization import keywords

video_list = ['NjUpQ7S8FL8','-VMrXnL93LA','oFfycdEUAXk','v8D2T9KwpWA','mu-XnFHj6y8','Js7kBVcFtJw','p5trtIlqFJs','nxUKHZlqFJA',
              'Fs50rS6oeF8','k86i8kVVDqU']


with open('Summaries.txt','w') as new_file:
  for video_key in video_list:
    texts = get_comment_threads(youtube, video_key)
    title = get_video_title(video_key)
    print('Title:', title)
    print('')
    print ('Summary:')   
    print (summarize(texts, ratio=0.15))

    print ('\nKeywords:')

    # higher ratio => more keywords
    print (keywords(texts, ratio=0.15))
    new_file.write('Title:'+ title+'\n\n')
    new_file.write('Summary:'+ summarize(texts, ratio=0.15)+'\n\n')
    new_file.write('Keywords:'+ keywords(texts, ratio=0.15)+'\n\n')

  
from google.colab import files
files.download("Summaries.txt")
# Out:
# dict_keys(['kind', 'etag', 'pageInfo', 'items'])
# Title: How to Sleep better?
#
# Summary:
# This has a strong relation to what is mentioned later in the lecture, where sleep deprivation has an effect equivalent to having the legal limit of blood alcohol concentration.
# 5:13 Taking a nap during the day can help in effective learning and improving alertness especially when you're feeling sleepy 3:50 I agree that learning just before sleep can help in retention.
# This helps me recover and allows me to concentrate on work and on training It is important for us to have a good sleep cycle.
# Depriving ourselves of sleep will only affect our focus and attention in the day.
# Time to go to bed I guess 2.09 I agree that not having enough sleep will have negative consequences for attention, working memory and cognitive processing!
# 03:40 Sleep is important for memory consolidation and long-term storage of the things we learn.
# ...
